# %% [markdown]
# # Git & GitHub — Professional Edition
#
# A structured, book-quality notebook with explanations, diagrams, exercises, and decision frameworks.

# %% [markdown]
# ## Table of Contents
# - Foundations
# - Branching
# - Remotes & SSH
# - Collaboration (Fork & Contributor)
# - Integration (Merge/Rebase/Conflicts)
# - Undo & Recovery
# - Power Tools

# %% [markdown]
# ## Part I — Foundations
#
# ### Why this matters
# Understanding Git as a system of snapshots prevents confusion later.
#
# ### Concept Diagram
# ```
# Working Tree → Staging → Commit
# ```
#
# ### Key Takeaways
# - Git = snapshot system
# - 3 layers matter
#
# ### Exercise
# - init repo
# - add file
# - commit

# %%
git init -b main
git add .
git commit -m "first commit"

# %% [markdown]
# ## Part II — Branching
#
# ### Why this matters
# All collaboration depends on branches.
#
# ### Diagram
# ```
# main ──●──●
#         \
#          ●──● feature
# ```
#
# ### Key Takeaways
# - branch = pointer
# - isolate work
#
# ### Common Mistake
# Working directly on main
#
# ### Exercise
# - create branch
# - commit
# - switch back

# %%
git switch -c feature/test
git switch main

# %% [markdown]
# ## Part III — Remotes & SSH
#
# ### Why this matters
# Connect local work to shared repos.
#
# ### Key Idea
# origin = remote name
#
# ### SSH Command

# %%
ssh-keygen -t ed25519 -C "email"

# %% [markdown]
# ### Exercise
# - generate ssh
# - test connection

# %%
ssh -T git@github.com

# %% [markdown]
# ## Part IV — Collaboration
#
# ### Two models
# - Fork
# - Contributor
#
# ### Diagram
# ```
# upstream ← fork
# ```
#
# ### Key Takeaways
# - fork = no access
# - contributor = direct access
#
# ### Exercise
# - fork repo
# - create PR

# %% [markdown]
# ## Part V — Integration
#
# ### Merge vs Rebase
#
# ### Diagram
# ```
# merge → branch history
# rebase → linear history
# ```
#
# ### Decision Rule
# - shared → merge
# - local → rebase
#
# ### Conflict markers
# ```
# <<<<<<<
# =======
# >>>>>>>
# ```
#
# ### Exercise
# - create conflict
# - resolve

# %%
git merge feature
git rebase main

# %% [markdown]
# ## Part VI — Undo & Recovery
#
# ### Decision Framework
# ```
# local → reset
# shared → revert
# file → restore
# ```
#
# ### Key Takeaways
# - reset rewrites
# - revert is safe
#
# ### Exercise
# - undo commit

# %%
git reset --mixed HEAD~1
git revert HEAD

# %% [markdown]
# ## Part VII — Power Tools
#
# ### Tools
# - stash
# - tag
# - reflog
# - bisect
#
# ### Example

# %%
git stash
git tag v1.0

# %% [markdown]
# ## Final Summary
#
# Git = layers + workflows.
#
# Master:
# - branching
# - collaboration
# - integration
# - recovery
