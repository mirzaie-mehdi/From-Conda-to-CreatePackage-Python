# %% [markdown]
# # Introduction
#
# This is the first chapter of the book.

# %% [markdown]
# # Test

# %% [markdown]
# # environment

# %%
import numpy as np
x = np.linspace(0, 1, 5)
x
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])
